# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def set_style():
    # This sets reasonable defaults for font size for
    # a figure that will go in a paper
    sns.set_context("paper")
    
    sns.set(rc={'figure.figsize':(11.7, 5.27)})
    
    # Set the font to be serif, rather than sans
    sns.set(font='serif')
    
    # Make the background white, and specify the
    # specific font family
    sns.set_style("white", {
        "font.family": "serif",
        "font.serif": ["Times", "Palatino", "serif"]
    })
    
    sns.set_theme(style="ticks", palette="pastel")
    

set_style()

# %%
def parse_res(file, benchmark="not_provided"):
    try:
        with open(file, 'r') as f:
            lines = f.read().split("\n")
    except:
        print(f"{file} not found")
        return pd.DataFrame()
        
    data = []
    for line in lines:
        if line:
            try:
                script, time = line.split()
                if float(time) == 0.0:
                    raise Exception()
                sname = script.replace(".sh:", "")
                data.append([f"{sname}_{benchmark}", sname, float(time)])
            except:
                print(f"Skipping {line}")
    
    df = pd.DataFrame(data, columns=["uid", "benchname", "exec_time"])
    df = df.set_index("uid")
    return df

# %%
# folder = 'no_checksum'

def average_dfs(dfs):
    df = pd.concat(dfs)
    df = df.groupby('bench_name').mean()
    return df

def get_summary_per_mode(benchmarks, modes):
    # Returns a list of lists where each sublist contains all modes results for a benchmarks
    all_benchs = []
    for benchmark in benchmarks:
        dfs = {}
        for mode in modes:
            df = parse_res(f'{benchmark}/outputs/{mode}/{benchmark}.res', benchmark)
            dfs[mode] = df
        all_benchs.append((benchmark, dfs))
        
    summary_per_mode = {}
    for mode in modes:
        summary = []
        for benchmark, dfs in all_benchs:
            dfs[mode]['benchmark'] = benchmark
            summary.append(dfs[mode])

        new_df = pd.concat(summary, axis = 0)
        new_df['mode'] = mode
        summary_per_mode[mode] = new_df
    return summary_per_mode


def remap_labels(df):
    remap_mode = {'hadoopstreaming': "Hadoop-streaming", 'pash': "PaSh", 'dish': "DiSh", "naive": "Naive", "base": "Base", "optimized": "Optimized"}
    df['mode'] = df['mode'].map(remap_mode)
    remap_benchmark = {'nlp': 'NLP', 'oneliners': 'Classics', 'unix50': 'Unix50', 'covid-mts': 'COVID-mts'}
    df['benchmark'] = df['benchmark'].replace(remap_benchmark)
    df['benchname'] = df['benchname'].replace({ 'temp-analytics': 'AvgTemp' })
    return df
    

def get_speedup_df(summary_per_mode):
    dfs = []
    for mode in summary_per_mode:
        if mode == 'bash':
            continue
        summary_per_mode[mode]['speedup'] = summary_per_mode['bash']['exec_time']/summary_per_mode[mode]['exec_time']
        summary_per_mode[mode].dropna()
        dfs.append(summary_per_mode[mode])
    summary_df = pd.concat(dfs, axis = 0)
    summary_df.dropna()
    
    return remap_labels(summary_df)

# %%
# benchmarks = ["oneliners", "unix50", "analytics-mts", "max-temp", "nlp", "dependency_untangling"]
# modes = ["dish", "pash", "bash", 'hadoopstreaming']

benchmarks = ["nlp"]
modes = ["dish", "pash", "bash", 'naive', 'base', 'optimized']
summary_per_mode = get_summary_per_mode(benchmarks, modes)
summary_df = pd.concat(summary_per_mode, axis = 1)

# summary_df.to_csv("benchmarks.csv")  
def print_stats(df, baseline_mode, mode):
    speedup_df = pd.DataFrame()
    print(df)
    speedup_df['speedup'] = df[baseline_mode]['exec_time']/df[mode]['exec_time']
    speedup_df.dropna()
    print (f"{mode} speedup over {baseline_mode} stats:\n Mean {speedup_df['speedup'].mean()}, Max {speedup_df['speedup'].max()}, Min  {speedup_df['speedup'].min()}")
    
# print_stats(summary_per_mode, "seq", "hadoopstreaming")
print_stats(summary_per_mode, "bash", "pash")
print_stats(summary_per_mode, "bash", "dish")
print_stats(summary_per_mode, "bash", "naive")
print_stats(summary_per_mode, "bash", "base")
print_stats(summary_per_mode, "bash", "optimized")
# Out:
# Skipping executing nlp dish Tue May 28 09:12:53 AM UTC 2024
# Skipping executing nlp pash Tue May 28 11:49:15 AM UTC 2024
# Skipping executing nlp bash Tue May 28 03:34:28 AM UTC 2024
# Skipping executing nlp naive Tue May 28 09:23:08 AM UTC 2024
# Skipping executing nlp base Tue May 28 12:16:08 PM UTC 2024
# Skipping executing nlp optimized Tue May 28 10:24:11 AM UTC 2024
# {'dish':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     16.626       nlp  dish
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     16.677       nlp  dish
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     22.968       nlp  dish
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     12.864       nlp  dish
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.183       nlp  dish
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.193       nlp  dish
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     14.561       nlp  dish
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     14.933       nlp  dish
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.054       nlp  dish
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     13.879       nlp  dish
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     15.261       nlp  dish
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     12.643       nlp  dish
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     16.585       nlp  dish
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     20.313       nlp  dish
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     20.044       nlp  dish
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     15.572       nlp  dish
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     26.158       nlp  dish
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     11.464       nlp  dish
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     15.643       nlp  dish
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.404       nlp  dish
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     16.325       nlp  dish
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     16.575       nlp  dish, 'pash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       nlp  pash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       nlp  pash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       nlp  pash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       nlp  pash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       nlp  pash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     87.864       nlp  pash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     47.109       nlp  pash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     44.659       nlp  pash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     47.902       nlp  pash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     44.501       nlp  pash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     47.630       nlp  pash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     47.388       nlp  pash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     47.402       nlp  pash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     48.834       nlp  pash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     49.000       nlp  pash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     47.744       nlp  pash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     51.436       nlp  pash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     44.474       nlp  pash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     47.198       nlp  pash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    119.394       nlp  pash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     48.021       nlp  pash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     45.471       nlp  pash, 'bash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh    266.944       nlp  bash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh    259.099       nlp  bash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh    530.848       nlp  bash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh    284.336       nlp  bash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh    282.976       nlp  bash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh    529.464       nlp  bash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh    270.761       nlp  bash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh    254.575       nlp  bash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh    283.575       nlp  bash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh    254.718       nlp  bash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh    276.348       nlp  bash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh    282.353       nlp  bash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh    273.631       nlp  bash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh    280.696       nlp  bash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh    283.507       nlp  bash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh    278.434       nlp  bash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh    283.006       nlp  bash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh    256.976       nlp  bash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh    276.514       nlp  bash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    744.429       nlp  bash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh    275.841       nlp  bash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh    258.110       nlp  bash, 'naive':                                  benchname  exec_time benchmark   mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     17.894       nlp  naive
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     18.356       nlp  naive
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     25.712       nlp  naive
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     13.774       nlp  naive
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.888       nlp  naive
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.501       nlp  naive
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     15.417       nlp  naive
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     15.760       nlp  naive
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.807       nlp  naive
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     14.930       nlp  naive
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     16.680       nlp  naive
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     13.513       nlp  naive
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     17.614       nlp  naive
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     21.804       nlp  naive
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     21.513       nlp  naive
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     16.459       nlp  naive
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     28.761       nlp  naive
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     12.505       nlp  naive
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     16.543       nlp  naive
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.806       nlp  naive
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     17.394       nlp  naive
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     17.802       nlp  naive, 'base':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     24.568       nlp  base
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     24.549       nlp  base
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     38.745       nlp  base
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     19.531       nlp  base
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     22.926       nlp  base
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     28.492       nlp  base
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     21.319       nlp  base
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     22.595       nlp  base
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     19.926       nlp  base
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     20.825       nlp  base
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     22.809       nlp  base
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     19.270       nlp  base
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     24.527       nlp  base
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     27.742       nlp  base
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     27.464       nlp  base
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     23.236       nlp  base
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     33.748       nlp  base
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     19.123       nlp  base
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     23.322       nlp  base
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     46.866       nlp  base
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     23.480       nlp  base
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     24.225       nlp  base, 'optimized':                                  benchname  exec_time benchmark       mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     21.974       nlp  optimized
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     21.843       nlp  optimized
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     41.579       nlp  optimized
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     23.647       nlp  optimized
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     23.765       nlp  optimized
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     31.319       nlp  optimized
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     23.874       nlp  optimized
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     23.500       nlp  optimized
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     25.040       nlp  optimized
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     24.425       nlp  optimized
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     24.815       nlp  optimized
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     25.173       nlp  optimized
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     25.236       nlp  optimized
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     26.989       nlp  optimized
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     26.892       nlp  optimized
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     26.309       nlp  optimized
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     34.440       nlp  optimized
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       nlp  optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       nlp  optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       nlp  optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       nlp  optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       nlp  optimized}
# pash speedup over bash stats:
#  Mean 5.812007148070564, Max 6.235062063420272, Min  5.5020996967104745
# {'dish':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     16.626       nlp  dish
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     16.677       nlp  dish
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     22.968       nlp  dish
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     12.864       nlp  dish
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.183       nlp  dish
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.193       nlp  dish
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     14.561       nlp  dish
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     14.933       nlp  dish
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.054       nlp  dish
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     13.879       nlp  dish
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     15.261       nlp  dish
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     12.643       nlp  dish
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     16.585       nlp  dish
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     20.313       nlp  dish
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     20.044       nlp  dish
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     15.572       nlp  dish
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     26.158       nlp  dish
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     11.464       nlp  dish
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     15.643       nlp  dish
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.404       nlp  dish
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     16.325       nlp  dish
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     16.575       nlp  dish, 'pash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       nlp  pash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       nlp  pash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       nlp  pash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       nlp  pash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       nlp  pash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     87.864       nlp  pash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     47.109       nlp  pash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     44.659       nlp  pash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     47.902       nlp  pash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     44.501       nlp  pash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     47.630       nlp  pash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     47.388       nlp  pash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     47.402       nlp  pash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     48.834       nlp  pash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     49.000       nlp  pash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     47.744       nlp  pash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     51.436       nlp  pash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     44.474       nlp  pash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     47.198       nlp  pash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    119.394       nlp  pash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     48.021       nlp  pash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     45.471       nlp  pash, 'bash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh    266.944       nlp  bash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh    259.099       nlp  bash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh    530.848       nlp  bash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh    284.336       nlp  bash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh    282.976       nlp  bash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh    529.464       nlp  bash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh    270.761       nlp  bash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh    254.575       nlp  bash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh    283.575       nlp  bash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh    254.718       nlp  bash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh    276.348       nlp  bash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh    282.353       nlp  bash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh    273.631       nlp  bash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh    280.696       nlp  bash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh    283.507       nlp  bash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh    278.434       nlp  bash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh    283.006       nlp  bash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh    256.976       nlp  bash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh    276.514       nlp  bash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    744.429       nlp  bash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh    275.841       nlp  bash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh    258.110       nlp  bash, 'naive':                                  benchname  exec_time benchmark   mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     17.894       nlp  naive
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     18.356       nlp  naive
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     25.712       nlp  naive
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     13.774       nlp  naive
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.888       nlp  naive
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.501       nlp  naive
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     15.417       nlp  naive
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     15.760       nlp  naive
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.807       nlp  naive
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     14.930       nlp  naive
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     16.680       nlp  naive
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     13.513       nlp  naive
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     17.614       nlp  naive
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     21.804       nlp  naive
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     21.513       nlp  naive
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     16.459       nlp  naive
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     28.761       nlp  naive
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     12.505       nlp  naive
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     16.543       nlp  naive
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.806       nlp  naive
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     17.394       nlp  naive
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     17.802       nlp  naive, 'base':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     24.568       nlp  base
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     24.549       nlp  base
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     38.745       nlp  base
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     19.531       nlp  base
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     22.926       nlp  base
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     28.492       nlp  base
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     21.319       nlp  base
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     22.595       nlp  base
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     19.926       nlp  base
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     20.825       nlp  base
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     22.809       nlp  base
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     19.270       nlp  base
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     24.527       nlp  base
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     27.742       nlp  base
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     27.464       nlp  base
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     23.236       nlp  base
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     33.748       nlp  base
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     19.123       nlp  base
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     23.322       nlp  base
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     46.866       nlp  base
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     23.480       nlp  base
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     24.225       nlp  base, 'optimized':                                  benchname  exec_time benchmark       mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     21.974       nlp  optimized
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     21.843       nlp  optimized
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     41.579       nlp  optimized
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     23.647       nlp  optimized
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     23.765       nlp  optimized
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     31.319       nlp  optimized
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     23.874       nlp  optimized
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     23.500       nlp  optimized
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     25.040       nlp  optimized
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     24.425       nlp  optimized
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     24.815       nlp  optimized
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     25.173       nlp  optimized
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     25.236       nlp  optimized
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     26.989       nlp  optimized
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     26.892       nlp  optimized
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     26.309       nlp  optimized
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     34.440       nlp  optimized
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       nlp  optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       nlp  optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       nlp  optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       nlp  optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       nlp  optimized}
# dish speedup over bash stats:
#  Mean 17.98257563570789, Max 23.11250435388366, Min  10.81909931951984
# {'dish':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     16.626       nlp  dish
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     16.677       nlp  dish
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     22.968       nlp  dish
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     12.864       nlp  dish
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.183       nlp  dish
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.193       nlp  dish
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     14.561       nlp  dish
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     14.933       nlp  dish
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.054       nlp  dish
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     13.879       nlp  dish
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     15.261       nlp  dish
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     12.643       nlp  dish
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     16.585       nlp  dish
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     20.313       nlp  dish
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     20.044       nlp  dish
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     15.572       nlp  dish
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     26.158       nlp  dish
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     11.464       nlp  dish
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     15.643       nlp  dish
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.404       nlp  dish
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     16.325       nlp  dish
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     16.575       nlp  dish, 'pash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       nlp  pash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       nlp  pash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       nlp  pash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       nlp  pash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       nlp  pash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     87.864       nlp  pash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     47.109       nlp  pash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     44.659       nlp  pash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     47.902       nlp  pash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     44.501       nlp  pash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     47.630       nlp  pash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     47.388       nlp  pash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     47.402       nlp  pash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     48.834       nlp  pash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     49.000       nlp  pash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     47.744       nlp  pash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     51.436       nlp  pash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     44.474       nlp  pash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     47.198       nlp  pash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    119.394       nlp  pash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     48.021       nlp  pash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     45.471       nlp  pash, 'bash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh    266.944       nlp  bash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh    259.099       nlp  bash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh    530.848       nlp  bash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh    284.336       nlp  bash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh    282.976       nlp  bash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh    529.464       nlp  bash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh    270.761       nlp  bash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh    254.575       nlp  bash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh    283.575       nlp  bash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh    254.718       nlp  bash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh    276.348       nlp  bash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh    282.353       nlp  bash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh    273.631       nlp  bash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh    280.696       nlp  bash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh    283.507       nlp  bash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh    278.434       nlp  bash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh    283.006       nlp  bash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh    256.976       nlp  bash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh    276.514       nlp  bash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    744.429       nlp  bash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh    275.841       nlp  bash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh    258.110       nlp  bash, 'naive':                                  benchname  exec_time benchmark   mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     17.894       nlp  naive
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     18.356       nlp  naive
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     25.712       nlp  naive
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     13.774       nlp  naive
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.888       nlp  naive
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.501       nlp  naive
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     15.417       nlp  naive
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     15.760       nlp  naive
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.807       nlp  naive
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     14.930       nlp  naive
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     16.680       nlp  naive
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     13.513       nlp  naive
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     17.614       nlp  naive
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     21.804       nlp  naive
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     21.513       nlp  naive
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     16.459       nlp  naive
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     28.761       nlp  naive
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     12.505       nlp  naive
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     16.543       nlp  naive
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.806       nlp  naive
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     17.394       nlp  naive
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     17.802       nlp  naive, 'base':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     24.568       nlp  base
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     24.549       nlp  base
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     38.745       nlp  base
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     19.531       nlp  base
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     22.926       nlp  base
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     28.492       nlp  base
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     21.319       nlp  base
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     22.595       nlp  base
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     19.926       nlp  base
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     20.825       nlp  base
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     22.809       nlp  base
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     19.270       nlp  base
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     24.527       nlp  base
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     27.742       nlp  base
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     27.464       nlp  base
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     23.236       nlp  base
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     33.748       nlp  base
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     19.123       nlp  base
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     23.322       nlp  base
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     46.866       nlp  base
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     23.480       nlp  base
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     24.225       nlp  base, 'optimized':                                  benchname  exec_time benchmark       mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     21.974       nlp  optimized
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     21.843       nlp  optimized
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     41.579       nlp  optimized
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     23.647       nlp  optimized
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     23.765       nlp  optimized
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     31.319       nlp  optimized
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     23.874       nlp  optimized
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     23.500       nlp  optimized
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     25.040       nlp  optimized
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     24.425       nlp  optimized
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     24.815       nlp  optimized
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     25.173       nlp  optimized
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     25.236       nlp  optimized
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     26.989       nlp  optimized
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     26.892       nlp  optimized
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     26.309       nlp  optimized
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     34.440       nlp  optimized
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       nlp  optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       nlp  optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       nlp  optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       nlp  optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       nlp  optimized}
# naive speedup over bash stats:
#  Mean 16.85555076820502, Max 21.609893473735767, Min  9.839922116755327
# {'dish':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     16.626       nlp  dish
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     16.677       nlp  dish
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     22.968       nlp  dish
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     12.864       nlp  dish
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.183       nlp  dish
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.193       nlp  dish
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     14.561       nlp  dish
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     14.933       nlp  dish
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.054       nlp  dish
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     13.879       nlp  dish
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     15.261       nlp  dish
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     12.643       nlp  dish
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     16.585       nlp  dish
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     20.313       nlp  dish
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     20.044       nlp  dish
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     15.572       nlp  dish
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     26.158       nlp  dish
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     11.464       nlp  dish
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     15.643       nlp  dish
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.404       nlp  dish
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     16.325       nlp  dish
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     16.575       nlp  dish, 'pash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       nlp  pash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       nlp  pash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       nlp  pash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       nlp  pash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       nlp  pash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     87.864       nlp  pash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     47.109       nlp  pash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     44.659       nlp  pash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     47.902       nlp  pash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     44.501       nlp  pash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     47.630       nlp  pash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     47.388       nlp  pash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     47.402       nlp  pash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     48.834       nlp  pash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     49.000       nlp  pash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     47.744       nlp  pash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     51.436       nlp  pash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     44.474       nlp  pash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     47.198       nlp  pash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    119.394       nlp  pash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     48.021       nlp  pash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     45.471       nlp  pash, 'bash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh    266.944       nlp  bash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh    259.099       nlp  bash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh    530.848       nlp  bash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh    284.336       nlp  bash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh    282.976       nlp  bash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh    529.464       nlp  bash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh    270.761       nlp  bash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh    254.575       nlp  bash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh    283.575       nlp  bash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh    254.718       nlp  bash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh    276.348       nlp  bash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh    282.353       nlp  bash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh    273.631       nlp  bash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh    280.696       nlp  bash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh    283.507       nlp  bash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh    278.434       nlp  bash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh    283.006       nlp  bash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh    256.976       nlp  bash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh    276.514       nlp  bash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    744.429       nlp  bash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh    275.841       nlp  bash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh    258.110       nlp  bash, 'naive':                                  benchname  exec_time benchmark   mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     17.894       nlp  naive
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     18.356       nlp  naive
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     25.712       nlp  naive
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     13.774       nlp  naive
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.888       nlp  naive
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.501       nlp  naive
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     15.417       nlp  naive
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     15.760       nlp  naive
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.807       nlp  naive
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     14.930       nlp  naive
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     16.680       nlp  naive
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     13.513       nlp  naive
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     17.614       nlp  naive
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     21.804       nlp  naive
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     21.513       nlp  naive
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     16.459       nlp  naive
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     28.761       nlp  naive
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     12.505       nlp  naive
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     16.543       nlp  naive
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.806       nlp  naive
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     17.394       nlp  naive
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     17.802       nlp  naive, 'base':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     24.568       nlp  base
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     24.549       nlp  base
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     38.745       nlp  base
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     19.531       nlp  base
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     22.926       nlp  base
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     28.492       nlp  base
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     21.319       nlp  base
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     22.595       nlp  base
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     19.926       nlp  base
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     20.825       nlp  base
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     22.809       nlp  base
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     19.270       nlp  base
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     24.527       nlp  base
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     27.742       nlp  base
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     27.464       nlp  base
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     23.236       nlp  base
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     33.748       nlp  base
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     19.123       nlp  base
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     23.322       nlp  base
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     46.866       nlp  base
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     23.480       nlp  base
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     24.225       nlp  base, 'optimized':                                  benchname  exec_time benchmark       mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     21.974       nlp  optimized
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     21.843       nlp  optimized
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     41.579       nlp  optimized
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     23.647       nlp  optimized
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     23.765       nlp  optimized
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     31.319       nlp  optimized
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     23.874       nlp  optimized
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     23.500       nlp  optimized
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     25.040       nlp  optimized
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     24.425       nlp  optimized
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     24.815       nlp  optimized
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     25.173       nlp  optimized
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     25.236       nlp  optimized
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     26.989       nlp  optimized
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     26.892       nlp  optimized
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     26.309       nlp  optimized
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     34.440       nlp  optimized
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       nlp  optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       nlp  optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       nlp  optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       nlp  optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       nlp  optimized}
# base speedup over bash stats:
#  Mean 12.425026288193095, Max 18.58290046328794, Min  8.385859902809056
# {'dish':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     16.626       nlp  dish
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     16.677       nlp  dish
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     22.968       nlp  dish
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     12.864       nlp  dish
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.183       nlp  dish
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.193       nlp  dish
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     14.561       nlp  dish
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     14.933       nlp  dish
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.054       nlp  dish
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     13.879       nlp  dish
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     15.261       nlp  dish
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     12.643       nlp  dish
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     16.585       nlp  dish
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     20.313       nlp  dish
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     20.044       nlp  dish
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     15.572       nlp  dish
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     26.158       nlp  dish
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     11.464       nlp  dish
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     15.643       nlp  dish
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.404       nlp  dish
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     16.325       nlp  dish
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     16.575       nlp  dish, 'pash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       nlp  pash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       nlp  pash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       nlp  pash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       nlp  pash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       nlp  pash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     87.864       nlp  pash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     47.109       nlp  pash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     44.659       nlp  pash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     47.902       nlp  pash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     44.501       nlp  pash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     47.630       nlp  pash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     47.388       nlp  pash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     47.402       nlp  pash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     48.834       nlp  pash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     49.000       nlp  pash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     47.744       nlp  pash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     51.436       nlp  pash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     44.474       nlp  pash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     47.198       nlp  pash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    119.394       nlp  pash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     48.021       nlp  pash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     45.471       nlp  pash, 'bash':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh    266.944       nlp  bash
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh    259.099       nlp  bash
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh    530.848       nlp  bash
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh    284.336       nlp  bash
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh    282.976       nlp  bash
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh    529.464       nlp  bash
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh    270.761       nlp  bash
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh    254.575       nlp  bash
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh    283.575       nlp  bash
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh    254.718       nlp  bash
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh    276.348       nlp  bash
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh    282.353       nlp  bash
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh    273.631       nlp  bash
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh    280.696       nlp  bash
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh    283.507       nlp  bash
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh    278.434       nlp  bash
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh    283.006       nlp  bash
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh    256.976       nlp  bash
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh    276.514       nlp  bash
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh    744.429       nlp  bash
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh    275.841       nlp  bash
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh    258.110       nlp  bash, 'naive':                                  benchname  exec_time benchmark   mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     17.894       nlp  naive
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     18.356       nlp  naive
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     25.712       nlp  naive
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     13.774       nlp  naive
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     16.888       nlp  naive
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     24.501       nlp  naive
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     15.417       nlp  naive
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     15.760       nlp  naive
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     13.807       nlp  naive
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     14.930       nlp  naive
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     16.680       nlp  naive
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     13.513       nlp  naive
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     17.614       nlp  naive
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     21.804       nlp  naive
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     21.513       nlp  naive
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     16.459       nlp  naive
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     28.761       nlp  naive
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     12.505       nlp  naive
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     16.543       nlp  naive
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     42.806       nlp  naive
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     17.394       nlp  naive
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     17.802       nlp  naive, 'base':                                  benchname  exec_time benchmark  mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     24.568       nlp  base
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     24.549       nlp  base
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     38.745       nlp  base
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     19.531       nlp  base
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     22.926       nlp  base
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     28.492       nlp  base
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     21.319       nlp  base
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     22.595       nlp  base
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     19.926       nlp  base
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     20.825       nlp  base
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     22.809       nlp  base
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     19.270       nlp  base
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     24.527       nlp  base
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     27.742       nlp  base
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     27.464       nlp  base
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     23.236       nlp  base
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     33.748       nlp  base
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     19.123       nlp  base
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     23.322       nlp  base
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     46.866       nlp  base
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     23.480       nlp  base
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     24.225       nlp  base, 'optimized':                                  benchname  exec_time benchmark       mode
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     21.974       nlp  optimized
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     21.843       nlp  optimized
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     41.579       nlp  optimized
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     23.647       nlp  optimized
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     23.765       nlp  optimized
# ./scripts/8.3_3.sh_nlp  ./scripts/8.3_3.sh     31.319       nlp  optimized
# ./scripts/7_2.sh_nlp      ./scripts/7_2.sh     23.874       nlp  optimized
# ./scripts/7_1.sh_nlp      ./scripts/7_1.sh     23.500       nlp  optimized
# ./scripts/4_3b.sh_nlp    ./scripts/4_3b.sh     25.040       nlp  optimized
# ./scripts/2_2.sh_nlp      ./scripts/2_2.sh     24.425       nlp  optimized
# ./scripts/1_1.sh_nlp      ./scripts/1_1.sh     24.815       nlp  optimized
# ./scripts/8.3_2.sh_nlp  ./scripts/8.3_2.sh     25.173       nlp  optimized
# ./scripts/2_1.sh_nlp      ./scripts/2_1.sh     25.236       nlp  optimized
# ./scripts/3_1.sh_nlp      ./scripts/3_1.sh     26.989       nlp  optimized
# ./scripts/3_2.sh_nlp      ./scripts/3_2.sh     26.892       nlp  optimized
# ./scripts/8_1.sh_nlp      ./scripts/8_1.sh     26.309       nlp  optimized
# ./scripts/3_3.sh_nlp      ./scripts/3_3.sh     34.440       nlp  optimized
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       nlp  optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       nlp  optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       nlp  optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       nlp  optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       nlp  optimized}
# optimized speedup over bash stats:
#  Mean 11.383796156153506, Max 16.905520610492037, Min  8.217363530778165

# %%
def boxplot(df, x, y, savefig=None, ax=None):
    f = sns.boxplot(data=df, x = x, y = y, hue="mode", ax=ax)
    f.set(yscale='log')
    plt.legend(loc='upper left')
    f.set(xlabel='Benchmark')
    f.axhline(1, ls='--')
    if savefig:
        plt.savefig(savefig)
        
# benchmarks = ["oneliners", "unix50", "nlp", "analytics-mts"]
# modes = ["seq", 'hadoopstreaming', "par", "distr"]
benchmarks = ["nlp"]
modes = ["bash", 'pash', "dish", "naive", "base", "optimized"]
summary_per_mode = get_summary_per_mode(benchmarks, modes)
df1 = get_speedup_df(summary_per_mode)
print(df1)
boxplot(df1, x='benchmark', y='speedup', savefig="distr_boxplot.pdf")
# Out:
# Skipping executing nlp bash Tue May 28 03:34:28 AM UTC 2024
# Skipping executing nlp pash Tue May 28 11:49:15 AM UTC 2024
# Skipping executing nlp dish Tue May 28 09:12:53 AM UTC 2024
# Skipping executing nlp naive Tue May 28 09:23:08 AM UTC 2024
# Skipping executing nlp base Tue May 28 12:16:08 PM UTC 2024
# Skipping executing nlp optimized Tue May 28 10:24:11 AM UTC 2024
#                                  benchname  exec_time benchmark       mode  \
# uid
# ./scripts/6_4.sh_nlp      ./scripts/6_4.sh     47.136       NLP       PaSh
# ./scripts/6_5.sh_nlp      ./scripts/6_5.sh     46.248       NLP       PaSh
# ./scripts/6_2.sh_nlp      ./scripts/6_2.sh     86.888       NLP       PaSh
# ./scripts/8.2_2.sh_nlp  ./scripts/8.2_2.sh     47.950       NLP       PaSh
# ./scripts/4_3.sh_nlp      ./scripts/4_3.sh     49.226       NLP       PaSh
# ...                                    ...        ...       ...        ...
# ./scripts/6_1_1.sh_nlp  ./scripts/6_1_1.sh     26.138       NLP  Optimized
# ./scripts/6_1_2.sh_nlp  ./scripts/6_1_2.sh     26.920       NLP  Optimized
# ./scripts/6_7.sh_nlp      ./scripts/6_7.sh     44.779       NLP  Optimized
# ./scripts/8.2_1.sh_nlp  ./scripts/8.2_1.sh     27.885       NLP  Optimized
# ./scripts/6_3.sh_nlp      ./scripts/6_3.sh     27.627       NLP  Optimized
#
#                           speedup
# uid
# ./scripts/6_4.sh_nlp     5.663272
# ./scripts/6_5.sh_nlp     5.602383
# ./scripts/6_2.sh_nlp     6.109566
# ./scripts/8.2_2.sh_nlp   5.929844
# ./scripts/4_3.sh_nlp     5.748507
# ...                           ...
# ./scripts/6_1_1.sh_nlp   9.831510
# ./scripts/6_1_2.sh_nlp  10.271694
# ./scripts/6_7.sh_nlp    16.624511
# ./scripts/8.2_1.sh_nlp   9.892093
# ./scripts/6_3.sh_nlp     9.342672
#
# [110 rows x 5 columns]

# %%
def speedup_barplot(df, x, y, savefig=None, ax=None):
    f = sns.barplot(data=df, x=x, y = y, hue="mode", ax=ax)
    f.set(xlabel='Benchmark')
    f.axhline(1, ls='--')
    plt.legend(loc='upper left')
    plt.xticks(rotation=45)
    plt.tight_layout()
    f.set(yscale='log')
    if savefig:
        plt.savefig(savefig)
        
benchmarks = ["dependency_untangling", "max-temp"]
modes = ["seq", "hadoopstreaming", "par", "distr"]

summary_per_mode = get_summary_per_mode(benchmarks, modes)
df2 = get_speedup_df(summary_per_mode)
speedup_barplot(df2, 'benchname', 'speedup', "par_vs_distr_barplot.pdf")
# Out:
# dependency_untangling/outputs/seq/dependency_untangling.res not found
# dependency_untangling/outputs/hadoopstreaming/dependency_untangling.res not found
# dependency_untangling/outputs/par/dependency_untangling.res not found
# dependency_untangling/outputs/distr/dependency_untangling.res not found
# max-temp/outputs/seq/max-temp.res not found
# max-temp/outputs/hadoopstreaming/max-temp.res not found
# max-temp/outputs/par/max-temp.res not found
# max-temp/outputs/distr/max-temp.res not found
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 16
#      13 modes = ["seq", "hadoopstreaming", "par", "distr"]
#      15 summary_per_mode = get_summary_per_mode(benchmarks, modes)
# ---> 16 df2 = get_speedup_df(summary_per_mode)
#      17 speedup_barplot(df2, 'benchname', 'speedup', "par_vs_distr_barplot.pdf")
#
# Cell In[13], line 45, in get_speedup_df(summary_per_mode)
#      43 if mode == 'bash':
#      44     continue
# ---> 45 summary_per_mode[mode]['speedup'] = summary_per_mode['bash']['exec_time']/summary_per_mode[mode]['exec_time']
#      46 summary_per_mode[mode].dropna()
#      47 dfs.append(summary_per_mode[mode])
#
# KeyError: 'bash'

# %%
fig, ax = plt.subplots(1,2, sharey=True, gridspec_kw={'width_ratios': [2.5, 3]})
boxplot(df1, 'benchmark', 'speedup', None, ax[0])
ax[0].legend().set_visible(False)
speedup_barplot(df2, 'benchname', 'speedup', None, ax[1])
leg = plt.legend( loc = 'upper right')
# ax[1].legend().set(loc='upper right')
for axis in ax:
    axis.set(ylim=(0.4, 200))
    axis.set_xticklabels(axis.get_xticklabels(), rotation = 25)
    axis.set(xlabel=None)
    

ax[0].set(ylabel="Speedup (log-scale)")
ax[1].set(ylabel=None)
# ax[1].get_yaxis().set_ticks([])
ax[1].tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
#     left=True,      # ticks along the bottom edge are off
    labelleft=False)

# fig.supxlabel('Benchmark')
fig.set_size_inches(14, 3, forward=True)

plt.tight_layout()


# fig.show()
plt.savefig("full_benchmarks_speedup.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 boxplot(df1, 'benchmark', 'speedup', None, ax[0])
#       3 ax[0].legend().set_visible(False)
# ----> 4 speedup_barplot(df2, 'benchname', 'speedup', None, ax[1])
#       5 leg = plt.legend( loc = 'upper right')
#       6 # ax[1].legend().set(loc='upper right')
#
# NameError: name 'df2' is not defined

# %%
benchmarks = ["oneliners", "unix50", "nlp", "analytics-mts"]
modes = ["seq", "distr_no_du", "distr"]
summary_per_mode = get_summary_per_mode(["nlp"], modes)
df1_1 = get_speedup_df(summary_per_mode)

summary_per_mode = get_summary_per_mode(["dependency_untangling", "max-temp"], modes)
df2_1 = get_speedup_df(summary_per_mode)

fig, ax = plt.subplots(1,2, gridspec_kw={'width_ratios': [2, 5]})
boxplot(df1_1, 'benchmark', 'speedup', None, ax[0])
ax[0].legend().set_visible(False)
speedup_barplot(df2_1, 'benchname', 'speedup', None, ax[1])
# ax[0].legend().set_visible(False)

for axis in ax:
    axis.set(ylim=(0.4, 200))
    axis.set_xticklabels(axis.get_xticklabels(), rotation = 25)
    axis.set(xlabel=None)
    

ax[0].set(ylabel="Speedup (log-scale)")
ax[1].set(ylabel=None)
# ax[1].get_yaxis().set_ticks([])
ax[1].tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
#     left=True,      # ticks along the bottom edge are off
    labelleft=False)

# fig.supxlabel('Benchmark')

plt.tight_layout()

fig.set_size_inches(7, 3, forward=True)

plt.tight_layout()

# fig.show()
plt.savefig("dependency_untangling_speedup.pdf")
# Out:
# No handles with labels found to put in legend.
# Skipping executing Unix-for-nlp Fri Jun 17 08:30:47 UTC 2022
# Skipping executing Unix-for-nlp with distr_no_du pash Fri Jun 17 10:33:59 UTC 2022
# Skipping executing Unix-for-nlp with distr pash Fri Jun 17 11:26:24 UTC 2022
# Skipping executing dependency_untangling Thu Jun 16 23:21:59 UTC 2022
# Skipping executing dependency_untangling with pash Fri Jun 17 00:10:39 UTC 2022
# Skipping executing dependency_untangling with pash Fri Jun 17 00:39:17 UTC 2022
# Skipping executing max temp Fri Jun 17 00:44:48 UTC 2022
# Skipping executing max-temp with distr_no_du pash Fri Jun 17 01:15:38 UTC 2022
# Skipping executing max-temp with distr pash Fri Jun 17 01:15:47 UTC 2022
